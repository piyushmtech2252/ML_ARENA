# %% [markdown]
# # Introduction to Computer Vision - Mid Semester Exam
#
# ## Instructions
# - Use **OpenCV (cv2)** for all image processing operations.
# - Use **Matplotlib** only for displaying the images.
# - Display the output of each task with a proper title.
# - Turn off axes while displaying images.

# %%
# Import Libraries

# %% [markdown]
# ## Read the Image

# %%
# Read Image

# %% [markdown]
# ## 1. Show the Blue Channel of Image

# %%
# Write your code here

# %% [markdown]
# ## 2. Convert Image into Grayscale and Show It

# %%
# Write your code here

# %% [markdown]
# ## 3. Resize Image to 1000 × 400 and Show It

# %%
# Write your code here

# %% [markdown]
# ## 4. Translate Image by 200 (X-axis) and 100 (Y-axis) and Show It

# %%
# Write your code here

# %% [markdown]
# ## 5. Rotate Image by 45 Degrees and Show It

# %%
# Write your code here

# %% [markdown]
# ## 6. Generate Negative Image and Show It

# %%
# Write your code here

# %% [markdown]
# ## 7. Apply Log Transform on Image and Show It

# %%
# Write your code here

# %% [markdown]
# ## 8. Equalise the Histogram of Image and Show It

# %%
# Write your code here

# %% [markdown]
# ## 9. Apply Erosion, Closing and Gradient Operation on Image and Show It

# %%
# Write your code here
